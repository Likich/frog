# %% [markdown]
# # Imports and setup

# %% [markdown]
# This will be necessary since Tatoeba is in iso 639-3 code format

# %%
# !pip install python-iso639
import iso639
# Out:
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (2023.6.15)

# %% [markdown]
# We want to load up our data from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# basic libraries
import os
import re
import pickle
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

# visualization tools
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

# model building tools
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Load data from google drive

# %% [markdown]
# ## Flores data

# %% [markdown]
# ### Loading Flores dataset

# %%
# !cp /content/drive/MyDrive/flores200_dataset.tar.gz .
# !tar -xvzf flores200_dataset.tar.gz;
# Out:
# ./flores200_dataset/
# ./flores200_dataset/README
# ./flores200_dataset/metadata_devtest.tsv
# ./flores200_dataset/devtest/
# ./flores200_dataset/devtest/glg_Latn.devtest
# ./flores200_dataset/devtest/swe_Latn.devtest
# ./flores200_dataset/devtest/war_Latn.devtest
# ./flores200_dataset/devtest/ltz_Latn.devtest
# ./flores200_dataset/devtest/lit_Latn.devtest
# ./flores200_dataset/devtest/tur_Latn.devtest
# ./flores200_dataset/devtest/bjn_Arab.devtest
# ./flores200_dataset/devtest/pbt_Arab.devtest
# ./flores200_dataset/devtest/asm_Beng.devtest
# ./flores200_dataset/devtest/kas_Deva.devtest
# ./flores200_dataset/devtest/kor_Hang.devtest
# ./flores200_dataset/devtest/aeb_Arab.devtest
# ./flores200_dataset/devtest/dan_Latn.devtest
# ./flores200_dataset/devtest/est_Latn.devtest
# ./flores200_dataset/devtest/tir_Ethi.devtest
# ./flores200_dataset/devtest/kin_Latn.devtest
# ./flores200_dataset/devtest/zsm_Latn.devtest
# ./flores200_dataset/devtest/ars_Arab.devtest
# ./flores200_dataset/devtest/cym_Latn.devtest
# ./flores200_dataset/devtest/kmr_Latn.devtest
# ./flores200_dataset/devtest/uzn_Latn.devtest
# ./flores200_dataset/devtest/ces_Latn.devtest
# ./flores200_dataset/devtest/ckb_Arab.devtest
# ./flores200_dataset/devtest/fon_Latn.devtest
# ./flores200_dataset/devtest/ind_Latn.devtest
# ./flores200_dataset/devtest/cat_Latn.devtest
# ./flores200_dataset/devtest/fur_Latn.devtest
# ./flores200_dataset/devtest/sot_Latn.devtest
# ./flores200_dataset/devtest/bod_Tibt.devtest
# ./flores200_dataset/devtest/tgk_Cyrl.devtest
# ./flores200_dataset/devtest/fra_Latn.devtest
# ./flores200_dataset/devtest/aka_Latn.devtest
# ./flores200_dataset/devtest/ajp_Arab.devtest
# ./flores200_dataset/devtest/mag_Deva.devtest
# ./flores200_dataset/devtest/kea_Latn.devtest
# ./flores200_dataset/devtest/grn_Latn.devtest
# ./flores200_dataset/devtest/snd_Arab.devtest
# ./flores200_dataset/devtest/als_Latn.devtest
# ./flores200_dataset/devtest/tel_Telu.devtest
# ./flores200_dataset/devtest/bjn_Latn.devtest
# ./flores200_dataset/devtest/hun_Latn.devtest
# ./flores200_dataset/devtest/arz_Arab.devtest
# ./flores200_dataset/devtest/quy_Latn.devtest
# ./flores200_dataset/devtest/taq_Tfng.devtest
# ./flores200_dataset/devtest/lin_Latn.devtest
# ./flores200_dataset/devtest/mya_Mymr.devtest
# ./flores200_dataset/devtest/hne_Deva.devtest
# ./flores200_dataset/devtest/run_Latn.devtest
# ./flores200_dataset/devtest/nus_Latn.devtest
# ./flores200_dataset/devtest/sat_Olck.devtest
# ./flores200_dataset/devtest/afr_Latn.devtest
# ./flores200_dataset/devtest/nld_Latn.devtest
# ./flores200_dataset/devtest/nso_Latn.devtest
# ./flores200_dataset/devtest/tum_Latn.devtest
# ./flores200_dataset/devtest/tam_Taml.devtest
# ./flores200_dataset/devtest/pan_Guru.devtest
# ./flores200_dataset/devtest/tso_Latn.devtest
# ./flores200_dataset/devtest/slv_Latn.devtest
# ./flores200_dataset/devtest/ace_Latn.devtest
# ./flores200_dataset/devtest/hye_Armn.devtest
# ./flores200_dataset/devtest/ceb_Latn.devtest
# ./flores200_dataset/devtest/fuv_Latn.devtest
# ./flores200_dataset/devtest/dik_Latn.devtest
# ./flores200_dataset/devtest/tpi_Latn.devtest
# ./flores200_dataset/devtest/hat_Latn.devtest
# ./flores200_dataset/devtest/lvs_Latn.devtest
# ./flores200_dataset/devtest/ory_Orya.devtest
# ./flores200_dataset/devtest/prs_Arab.devtest
# ./flores200_dataset/devtest/szl_Latn.devtest
# ./flores200_dataset/devtest/bul_Cyrl.devtest
# ./flores200_dataset/devtest/kac_Latn.devtest
# ./flores200_dataset/devtest/knc_Latn.devtest
# ./flores200_dataset/devtest/nob_Latn.devtest
# ./flores200_dataset/devtest/ewe_Latn.devtest
# ./flores200_dataset/devtest/kan_Knda.devtest
# ./flores200_dataset/devtest/lao_Laoo.devtest
# ./flores200_dataset/devtest/sna_Latn.devtest
# ./flores200_dataset/devtest/ibo_Latn.devtest
# ./flores200_dataset/devtest/tha_Thai.devtest
# ./flores200_dataset/devtest/acm_Arab.devtest
# ./flores200_dataset/devtest/mal_Mlym.devtest
# ./flores200_dataset/devtest/hau_Latn.devtest
# ./flores200_dataset/devtest/jav_Latn.devtest
# ./flores200_dataset/devtest/kik_Latn.devtest
# ./flores200_dataset/devtest/spa_Latn.devtest
# ./flores200_dataset/devtest/knc_Arab.devtest
# ./flores200_dataset/devtest/lug_Latn.devtest
# ./flores200_dataset/devtest/smo_Latn.devtest
# ./flores200_dataset/devtest/srd_Latn.devtest
# ./flores200_dataset/devtest/swh_Latn.devtest
# ./flores200_dataset/devtest/kab_Latn.devtest
# ./flores200_dataset/devtest/ast_Latn.devtest
# ./flores200_dataset/devtest/bam_Latn.devtest
# ./flores200_dataset/devtest/yor_Latn.devtest
# ./flores200_dataset/devtest/lij_Latn.devtest
# ./flores200_dataset/devtest/uig_Arab.devtest
# ./flores200_dataset/devtest/xho_Latn.devtest
# ./flores200_dataset/devtest/mri_Latn.devtest
# ./flores200_dataset/devtest/twi_Latn.devtest
# ./flores200_dataset/devtest/san_Deva.devtest
# ./flores200_dataset/devtest/mkd_Cyrl.devtest
# ./flores200_dataset/devtest/luo_Latn.devtest
# ./flores200_dataset/devtest/tsn_Latn.devtest
# ./flores200_dataset/devtest/ace_Arab.devtest
# ./flores200_dataset/devtest/eus_Latn.devtest
# ./flores200_dataset/devtest/kat_Geor.devtest
# ./flores200_dataset/devtest/mlt_Latn.devtest
# ./flores200_dataset/devtest/arb_Latn.devtest
# ./flores200_dataset/devtest/hin_Deva.devtest
# ./flores200_dataset/devtest/kmb_Latn.devtest
# ./flores200_dataset/devtest/gaz_Latn.devtest
# ./flores200_dataset/devtest/ydd_Hebr.devtest
# ./flores200_dataset/devtest/bug_Latn.devtest
# ./flores200_dataset/devtest/rus_Cyrl.devtest
# ./flores200_dataset/devtest/bos_Latn.devtest
# ./flores200_dataset/devtest/sag_Latn.devtest
# ./flores200_dataset/devtest/shn_Mymr.devtest
# ./flores200_dataset/devtest/awa_Deva.devtest
# ./flores200_dataset/devtest/cjk_Latn.devtest
# ./flores200_dataset/devtest/kir_Cyrl.devtest
# ./flores200_dataset/devtest/pap_Latn.devtest
# ./flores200_dataset/devtest/zho_Hans.devtest
# ./flores200_dataset/devtest/zul_Latn.devtest
# ./flores200_dataset/devtest/azb_Arab.devtest
# ./flores200_dataset/devtest/hrv_Latn.devtest
# ./flores200_dataset/devtest/sin_Sinh.devtest
# ./flores200_dataset/devtest/tgl_Latn.devtest
# ./flores200_dataset/devtest/lua_Latn.devtest
# ./flores200_dataset/devtest/npi_Deva.devtest
# ./flores200_dataset/devtest/ukr_Cyrl.devtest
# ./flores200_dataset/devtest/ell_Grek.devtest
# ./flores200_dataset/devtest/acq_Arab.devtest
# ./flores200_dataset/devtest/crh_Latn.devtest
# ./flores200_dataset/devtest/fin_Latn.devtest
# ./flores200_dataset/devtest/heb_Hebr.devtest
# ./flores200_dataset/devtest/kaz_Cyrl.devtest
# ./flores200_dataset/devtest/plt_Latn.devtest
# ./flores200_dataset/devtest/tzm_Tfng.devtest
# ./flores200_dataset/devtest/yue_Hant.devtest
# ./flores200_dataset/devtest/khm_Khmr.devtest
# ./flores200_dataset/devtest/kon_Latn.devtest
# ./flores200_dataset/devtest/nno_Latn.devtest
# ./flores200_dataset/devtest/ita_Latn.devtest
# ./flores200_dataset/devtest/vie_Latn.devtest
# ./flores200_dataset/devtest/mos_Latn.devtest
# ./flores200_dataset/devtest/kbp_Latn.devtest
# ./flores200_dataset/devtest/som_Latn.devtest
# ./flores200_dataset/devtest/urd_Arab.devtest
# ./flores200_dataset/devtest/slk_Latn.devtest
# ./flores200_dataset/devtest/azj_Latn.devtest
# ./flores200_dataset/devtest/dzo_Tibt.devtest
# ./flores200_dataset/devtest/fao_Latn.devtest
# ./flores200_dataset/devtest/lus_Latn.devtest
# ./flores200_dataset/devtest/khk_Cyrl.devtest
# ./flores200_dataset/devtest/vec_Latn.devtest
# ./flores200_dataset/devtest/arb_Arab.devtest
# ./flores200_dataset/devtest/lim_Latn.devtest
# ./flores200_dataset/devtest/tuk_Latn.devtest
# ./flores200_dataset/devtest/bho_Deva.devtest
# ./flores200_dataset/devtest/dyu_Latn.devtest
# ./flores200_dataset/devtest/ary_Arab.devtest
# ./flores200_dataset/devtest/bem_Latn.devtest
# ./flores200_dataset/devtest/kam_Latn.devtest
# ./flores200_dataset/devtest/por_Latn.devtest
# ./flores200_dataset/devtest/zho_Hant.devtest
# ./flores200_dataset/devtest/gle_Latn.devtest
# ./flores200_dataset/devtest/lmo_Latn.devtest
# ./flores200_dataset/devtest/bel_Cyrl.devtest
# ./flores200_dataset/devtest/mai_Deva.devtest
# ./flores200_dataset/devtest/pag_Latn.devtest
# ./flores200_dataset/devtest/scn_Latn.devtest
# ./flores200_dataset/devtest/bak_Cyrl.devtest
# ./flores200_dataset/devtest/deu_Latn.devtest
# ./flores200_dataset/devtest/jpn_Jpan.devtest
# ./flores200_dataset/devtest/mar_Deva.devtest
# ./flores200_dataset/devtest/pol_Latn.devtest
# ./flores200_dataset/devtest/mni_Beng.devtest
# ./flores200_dataset/devtest/amh_Ethi.devtest
# ./flores200_dataset/devtest/min_Arab.devtest
# ./flores200_dataset/devtest/ayr_Latn.devtest
# ./flores200_dataset/devtest/taq_Latn.devtest
# ./flores200_dataset/devtest/pes_Arab.devtest
# ./flores200_dataset/devtest/min_Latn.devtest
# ./flores200_dataset/devtest/wol_Latn.devtest
# ./flores200_dataset/devtest/guj_Gujr.devtest
# ./flores200_dataset/devtest/ssw_Latn.devtest
# ./flores200_dataset/devtest/isl_Latn.devtest
# ./flores200_dataset/devtest/sun_Latn.devtest
# ./flores200_dataset/devtest/epo_Latn.devtest
# ./flores200_dataset/devtest/fij_Latn.devtest
# ./flores200_dataset/devtest/tat_Cyrl.devtest
# ./flores200_dataset/devtest/eng_Latn.devtest
# ./flores200_dataset/devtest/ilo_Latn.devtest
# ./flores200_dataset/devtest/umb_Latn.devtest
# ./flores200_dataset/devtest/oci_Latn.devtest
# ./flores200_dataset/devtest/gla_Latn.devtest
# ./flores200_dataset/devtest/apc_Arab.devtest
# ./flores200_dataset/devtest/kas_Arab.devtest
# ./flores200_dataset/devtest/ltg_Latn.devtest
# ./flores200_dataset/devtest/ron_Latn.devtest
# ./flores200_dataset/devtest/ban_Latn.devtest
# ./flores200_dataset/devtest/ben_Beng.devtest
# ./flores200_dataset/devtest/nya_Latn.devtest
# ./flores200_dataset/devtest/srp_Cyrl.devtest
# ./flores200_dataset/dev/
# ./flores200_dataset/dev/ben_Beng.dev
# ./flores200_dataset/dev/acm_Arab.dev
# ./flores200_dataset/dev/pes_Arab.dev
# ./flores200_dataset/dev/lij_Latn.dev
# ./flores200_dataset/dev/wol_Latn.dev
# ./flores200_dataset/dev/uig_Arab.dev
# ./flores200_dataset/dev/slv_Latn.dev
# ./flores200_dataset/dev/quy_Latn.dev
# ./flores200_dataset/dev/tir_Ethi.dev
# ./flores200_dataset/dev/acq_Arab.dev
# ./flores200_dataset/dev/bem_Latn.dev
# ./flores200_dataset/dev/fin_Latn.dev
# ./flores200_dataset/dev/hat_Latn.dev
# ./flores200_dataset/dev/hye_Armn.dev
# ./flores200_dataset/dev/hne_Deva.dev
# ./flores200_dataset/dev/sot_Latn.dev
# ./flores200_dataset/dev/est_Latn.dev
# ./flores200_dataset/dev/por_Latn.dev
# ./flores200_dataset/dev/ces_Latn.dev
# ./flores200_dataset/dev/kbp_Latn.dev
# ./flores200_dataset/dev/snd_Arab.dev
# ./flores200_dataset/dev/zho_Hant.dev
# ./flores200_dataset/dev/isl_Latn.dev
# ./flores200_dataset/dev/kas_Deva.dev
# ./flores200_dataset/dev/aeb_Arab.dev
# ./flores200_dataset/dev/gla_Latn.dev
# ./flores200_dataset/dev/smo_Latn.dev
# ./flores200_dataset/dev/tgl_Latn.dev
# ./flores200_dataset/dev/kon_Latn.dev
# ./flores200_dataset/dev/pag_Latn.dev
# ./flores200_dataset/dev/mlt_Latn.dev
# ./flores200_dataset/dev/kan_Knda.dev
# ./flores200_dataset/dev/lin_Latn.dev
# ./flores200_dataset/dev/lmo_Latn.dev
# ./flores200_dataset/dev/tel_Telu.dev
# ./flores200_dataset/dev/awa_Deva.dev
# ./flores200_dataset/dev/npi_Deva.dev
# ./flores200_dataset/dev/ron_Latn.dev
# ./flores200_dataset/dev/umb_Latn.dev
# ./flores200_dataset/dev/apc_Arab.dev
# ./flores200_dataset/dev/cym_Latn.dev
# ./flores200_dataset/dev/deu_Latn.dev
# ./flores200_dataset/dev/plt_Latn.dev
# ./flores200_dataset/dev/spa_Latn.dev
# ./flores200_dataset/dev/vie_Latn.dev
# ./flores200_dataset/dev/fij_Latn.dev
# ./flores200_dataset/dev/zho_Hans.dev
# ./flores200_dataset/dev/ast_Latn.dev
# ./flores200_dataset/dev/lao_Laoo.dev
# ./flores200_dataset/dev/lua_Latn.dev
# ./flores200_dataset/dev/tam_Taml.dev
# ./flores200_dataset/dev/twi_Latn.dev
# ./flores200_dataset/dev/ceb_Latn.dev
# ./flores200_dataset/dev/azb_Arab.dev
# ./flores200_dataset/dev/khm_Khmr.dev
# ./flores200_dataset/dev/ckb_Arab.dev
# ./flores200_dataset/dev/heb_Hebr.dev
# ./flores200_dataset/dev/pbt_Arab.dev
# ./flores200_dataset/dev/run_Latn.dev
# ./flores200_dataset/dev/bul_Cyrl.dev
# ./flores200_dataset/dev/gle_Latn.dev
# ./flores200_dataset/dev/kac_Latn.dev
# ./flores200_dataset/dev/mri_Latn.dev
# ./flores200_dataset/dev/tur_Latn.dev
# ./flores200_dataset/dev/oci_Latn.dev
# ./flores200_dataset/dev/mya_Mymr.dev
# ./flores200_dataset/dev/nya_Latn.dev
# ./flores200_dataset/dev/als_Latn.dev
# ./flores200_dataset/dev/lim_Latn.dev
# ./flores200_dataset/dev/ibo_Latn.dev
# ./flores200_dataset/dev/swh_Latn.dev
# ./flores200_dataset/dev/nus_Latn.dev
# ./flores200_dataset/dev/tpi_Latn.dev
# ./flores200_dataset/dev/amh_Ethi.dev
# ./flores200_dataset/dev/ltg_Latn.dev
# ./flores200_dataset/dev/san_Deva.dev
# ./flores200_dataset/dev/sin_Sinh.dev
# ./flores200_dataset/dev/fao_Latn.dev
# ./flores200_dataset/dev/nld_Latn.dev
# ./flores200_dataset/dev/taq_Latn.dev
# ./flores200_dataset/dev/grn_Latn.dev
# ./flores200_dataset/dev/ilo_Latn.dev
# ./flores200_dataset/dev/kmr_Latn.dev
# ./flores200_dataset/dev/tum_Latn.dev
# ./flores200_dataset/dev/kea_Latn.dev
# ./flores200_dataset/dev/ita_Latn.dev
# ./flores200_dataset/dev/afr_Latn.dev
# ./flores200_dataset/dev/shn_Mymr.dev
# ./flores200_dataset/dev/ukr_Cyrl.dev
# ./flores200_dataset/dev/srp_Cyrl.dev
# ./flores200_dataset/dev/jpn_Jpan.dev
# ./flores200_dataset/dev/kam_Latn.dev
# ./flores200_dataset/dev/tgk_Cyrl.dev
# ./flores200_dataset/dev/uzn_Latn.dev
# ./flores200_dataset/dev/ell_Grek.dev
# ./flores200_dataset/dev/sat_Olck.dev
# ./flores200_dataset/dev/aka_Latn.dev
# ./flores200_dataset/dev/tzm_Tfng.dev
# ./flores200_dataset/dev/ydd_Hebr.dev
# ./flores200_dataset/dev/mal_Mlym.dev
# ./flores200_dataset/dev/nob_Latn.dev
# ./flores200_dataset/dev/ayr_Latn.dev
# ./flores200_dataset/dev/bak_Cyrl.dev
# ./flores200_dataset/dev/tso_Latn.dev
# ./flores200_dataset/dev/luo_Latn.dev
# ./flores200_dataset/dev/swe_Latn.dev
# ./flores200_dataset/dev/bos_Latn.dev
# ./flores200_dataset/dev/kik_Latn.dev
# ./flores200_dataset/dev/lus_Latn.dev
# ./flores200_dataset/dev/fra_Latn.dev
# ./flores200_dataset/dev/zsm_Latn.dev
# ./flores200_dataset/dev/pan_Guru.dev
# ./flores200_dataset/dev/scn_Latn.dev
# ./flores200_dataset/dev/kas_Arab.dev
# ./flores200_dataset/dev/mag_Deva.dev
# ./flores200_dataset/dev/mni_Beng.dev
# ./flores200_dataset/dev/slk_Latn.dev
# ./flores200_dataset/dev/lvs_Latn.dev
# ./flores200_dataset/dev/nso_Latn.dev
# ./flores200_dataset/dev/hin_Deva.dev
# ./flores200_dataset/dev/rus_Cyrl.dev
# ./flores200_dataset/dev/szl_Latn.dev
# ./flores200_dataset/dev/bam_Latn.dev
# ./flores200_dataset/dev/hau_Latn.dev
# ./flores200_dataset/dev/mar_Deva.dev
# ./flores200_dataset/dev/ory_Orya.dev
# ./flores200_dataset/dev/tuk_Latn.dev
# ./flores200_dataset/dev/ace_Latn.dev
# ./flores200_dataset/dev/eus_Latn.dev
# ./flores200_dataset/dev/knc_Arab.dev
# ./flores200_dataset/dev/dik_Latn.dev
# ./flores200_dataset/dev/hrv_Latn.dev
# ./flores200_dataset/dev/knc_Latn.dev
# ./flores200_dataset/dev/mos_Latn.dev
# ./flores200_dataset/dev/bho_Deva.dev
# ./flores200_dataset/dev/cjk_Latn.dev
# ./flores200_dataset/dev/ace_Arab.dev
# ./flores200_dataset/dev/ewe_Latn.dev
# ./flores200_dataset/dev/kat_Geor.dev
# ./flores200_dataset/dev/ssw_Latn.dev
# ./flores200_dataset/dev/ary_Arab.dev
# ./flores200_dataset/dev/azj_Latn.dev
# ./flores200_dataset/dev/epo_Latn.dev
# ./flores200_dataset/dev/eng_Latn.dev
# ./flores200_dataset/dev/crh_Latn.dev
# ./flores200_dataset/dev/kaz_Cyrl.dev
# ./flores200_dataset/dev/bel_Cyrl.dev
# ./flores200_dataset/dev/vec_Latn.dev
# ./flores200_dataset/dev/gaz_Latn.dev
# ./flores200_dataset/dev/bod_Tibt.dev
# ./flores200_dataset/dev/sna_Latn.dev
# ./flores200_dataset/dev/som_Latn.dev
# ./flores200_dataset/dev/guj_Gujr.dev
# ./flores200_dataset/dev/kab_Latn.dev
# ./flores200_dataset/dev/arz_Arab.dev
# ./flores200_dataset/dev/bjn_Arab.dev
# ./flores200_dataset/dev/kor_Hang.dev
# ./flores200_dataset/dev/yue_Hant.dev
# ./flores200_dataset/dev/zul_Latn.dev
# ./flores200_dataset/dev/fon_Latn.dev
# ./flores200_dataset/dev/hun_Latn.dev
# ./flores200_dataset/dev/urd_Arab.dev
# ./flores200_dataset/dev/sun_Latn.dev
# ./flores200_dataset/dev/tat_Cyrl.dev
# ./flores200_dataset/dev/taq_Tfng.dev
# ./flores200_dataset/dev/bjn_Latn.dev
# ./flores200_dataset/dev/srd_Latn.dev
# ./flores200_dataset/dev/mkd_Cyrl.dev
# ./flores200_dataset/dev/cat_Latn.dev
# ./flores200_dataset/dev/min_Latn.dev
# ./flores200_dataset/dev/fur_Latn.dev
# ./flores200_dataset/dev/glg_Latn.dev
# ./flores200_dataset/dev/kin_Latn.dev
# ./flores200_dataset/dev/mai_Deva.dev
# ./flores200_dataset/dev/sag_Latn.dev
# ./flores200_dataset/dev/ars_Arab.dev
# ./flores200_dataset/dev/ltz_Latn.dev
# ./flores200_dataset/dev/min_Arab.dev
# ./flores200_dataset/dev/jav_Latn.dev
# ./flores200_dataset/dev/arb_Latn.dev
# ./flores200_dataset/dev/dan_Latn.dev
# ./flores200_dataset/dev/kmb_Latn.dev
# ./flores200_dataset/dev/kir_Cyrl.dev
# ./flores200_dataset/dev/lug_Latn.dev
# ./flores200_dataset/dev/nno_Latn.dev
# ./flores200_dataset/dev/tha_Thai.dev
# ./flores200_dataset/dev/asm_Beng.dev
# ./flores200_dataset/dev/ban_Latn.dev
# ./flores200_dataset/dev/ind_Latn.dev
# ./flores200_dataset/dev/lit_Latn.dev
# ./flores200_dataset/dev/pap_Latn.dev
# ./flores200_dataset/dev/ajp_Arab.dev
# ./flores200_dataset/dev/arb_Arab.dev
# ./flores200_dataset/dev/prs_Arab.dev
# ./flores200_dataset/dev/fuv_Latn.dev
# ./flores200_dataset/dev/war_Latn.dev
# ./flores200_dataset/dev/tsn_Latn.dev
# ./flores200_dataset/dev/xho_Latn.dev
# ./flores200_dataset/dev/yor_Latn.dev
# ./flores200_dataset/dev/pol_Latn.dev
# ./flores200_dataset/dev/bug_Latn.dev
# ./flores200_dataset/dev/dyu_Latn.dev
# ./flores200_dataset/dev/khk_Cyrl.dev
# ./flores200_dataset/dev/dzo_Tibt.dev
# ./flores200_dataset/metadata_dev.tsv

# %%
# !head ./flores200_dataset/dev/ace_Arab.dev
# Out:
# يق أورو سنين، اوق علمون دري فکولتس کدوکترن يونيۏرسيتس ستانفورد ݢڤعموم اکن جتومى الت دياݢنوستيک بارو ڽڠ جوت ݢڤيليه اتو سيل منوروت جنيهجيه: چيڤ اوبيت ڽڠ جوت ݢچيتق ڽڠ جوت ݢڤݢت دڠون ڤرينتر ايڠ‌کجيت ستندر دڠون يوم موڠکين نا سابوه سين ا.س. لم تيڤ سابوه.
# ڤنليتي اوتام خن اترا ڽو موڠکين محسى ديتيکسي فون کى کنکر، ت.ب.س.، ايچ.اي.ۏي. ڠون مالاريا کى ڤاسيان دي نڠرو ڽڠ ݢاسين، ڽڠ توه تيڠکت کى اودڤ کى ڤڽاکيت لاݢى کنکر بوه دادا جوت ستڠوه دري نڠرو ڽڠ لوبيه کاي.
# جاس ۳۹سي ݢريڤين مڤوق لندسن ڤاچو ليڠک ڤوه ۹:۳۰ بڠوه دي سينن (۰۲۳۰ يوتيسي) ڠوت برتويه، سمڤو ݢتوڤ بندرا کى تربڠ کومرسيال.
# ڤيلوت ݢکالون ايدنتيتس سباݢو کڤالا سکوادرون ديلوکريت ڤاتاۏي.
# مديا دي سينن ݢڤتهى سابوه کندراءن ڤمادم اڤوي بندرا مݢولى واتى مجاوب.
# ۏيدل، ۲۸ تهون، کا مݢبوڠ ڠون بارسا لهى موسيم ڽڠ کا لوڤه، دري سيۏيلا.
# ڤفون ڤينه او ايبوکوتا کاتالن، ۏيدل کا ماءين ٤۹ ڤرتنديڠن کى کلوب ڽن.
# ڤروتيه کڤفون ليڠک ڤوه ١١:٠٠ واتى دي سينن (يوتيسي+١) دي وايتهال سبرڠ ڤينتو تاموڠ ڽڠ ݢکاواي ڤوليسي او داونيڠ ستريت، لم مليݢو رسمي ڤردان منترو.
# تڤت اوه لهوه ڤوه ١١:٠٠، اورڠ ڽڠ ڤروتيه ݢتوڤ لالو لينتس دي ݢربوڠ اوتارا دي وايتهال.
# بق ڤوه ١١:۲۰، ڤوليسي ملاکى اوق ڽڠ ڤروتيه ݢيسا او تروتوار، ڽڠ خن بهوا اوقڽن ڤرلى ݢڤئيمبڠ حق کى ڤروتيه ڠون لالو لينتس ڽڠ متومڤوق.

# %%
from glob import glob

# %%
def read_file(path):
  name = path.split('/')[-1][:3]
  try:
    i = iso639.Language.from_part3(name).name
  except iso639.LanguageNotFoundError:
    print('ignoring: ', name)
    return pd.DataFrame()
  with open(path, 'r') as file:
    lines = file.read().strip().split('\n')
  df = pd.DataFrame()
  df['text'] = lines
  df['language'] = name
  return df

# %%
flores_data = pd.concat([read_file(path) for path in glob('./flores200_dataset/dev/*.dev')], ignore_index=True)
flores_data
# Out:
# ignoring:  ajp
#                                                      text language
# 0       But shani hta Stanford dakkasu tsi dap kaw na ...      kac
# 1       Ndai arai hkyep gaw sinda mawng ana hpe sut su...      kac
# 2       JAS 39C Gripen mying ai pyenli gaw, buga ginda...      kac
# 3       Dai nbungli gau ai wa hpe Squadron a ning baw ...      kac
# 4       Buga shiga dap kaw na shapoi ai lam gaw, mahta...      kac
# ...                                                   ...      ...
# 202386  हिल स्टेशन के लेल पर्यटन के मौसम आम तौर पर भार...      mag
# 202387  हालांकि, सर्दी के दौरान ओकरा पास एगो अलग तरह क...      mag
# 202388  केवल कुछ एयरलाइंस अभीयो शोक किराया के पेशकश कर...      mag
# 202389  एयरलाइंस जे एगोर पेश करई हई ओइमे एयर कनाडा, डे...      mag
# 202390  सभे मामला में, अहां सीधे एयरलाइन के जौरे फोन द...      mag
#
# [202391 rows x 2 columns]

# %% [markdown]
# ### Cleaning data

# %%
flores_data.isna().any()
# Out:
# text        False
# language    False
# dtype: bool

# %% [markdown]
# ### Investigating

# %%
from collections import Counter
c = Counter((len(t.split()) for t in flores_data['text']))
labels, values = zip(*c.items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.yscale('log')
plt.title('histogram: # of words in sentence')
# Out:
# Text(0.5, 1.0, 'histogram: # of words in sentence')

# %%
plt.hist([len(df) for _,df in flores_data.groupby('language')], bins='auto')
plt.yscale('log')
plt.title('histogram: # of texts per language')
# Out:
# Text(0.5, 1.0, 'histogram: # of texts per language')

# %%
uniq = np.unique(flores_data.language)
uniq, uniq.shape
# Out:
# (array(['ace', 'acm', 'acq', 'aeb', 'afr', 'aka', 'als', 'amh', 'apc',
#         'arb', 'ars', 'ary', 'arz', 'asm', 'ast', 'awa', 'ayr', 'azb',
#         'azj', 'bak', 'bam', 'ban', 'bel', 'bem', 'ben', 'bho', 'bjn',
#         'bod', 'bos', 'bug', 'bul', 'cat', 'ceb', 'ces', 'cjk', 'ckb',
#         'crh', 'cym', 'dan', 'deu', 'dik', 'dyu', 'dzo', 'ell', 'eng',
#         'epo', 'est', 'eus', 'ewe', 'fao', 'fij', 'fin', 'fon', 'fra',
#         'fur', 'fuv', 'gaz', 'gla', 'gle', 'glg', 'grn', 'guj', 'hat',
#         'hau', 'heb', 'hin', 'hne', 'hrv', 'hun', 'hye', 'ibo', 'ilo',
#         'ind', 'isl', 'ita', 'jav', 'jpn', 'kab', 'kac', 'kam', 'kan',
#         'kas', 'kat', 'kaz', 'kbp', 'kea', 'khk', 'khm', 'kik', 'kin',
#         'kir', 'kmb', 'kmr', 'knc', 'kon', 'kor', 'lao', 'lij', 'lim',
#         'lin', 'lit', 'lmo', 'ltg', 'ltz', 'lua', 'lug', 'luo', 'lus',
#         'lvs', 'mag', 'mai', 'mal', 'mar', 'min', 'mkd', 'mlt', 'mni',
#         'mos', 'mri', 'mya', 'nld', 'nno', 'nob', 'npi', 'nso', 'nus',
#         'nya', 'oci', 'ory', 'pag', 'pan', 'pap', 'pbt', 'pes', 'plt',
#         'pol', 'por', 'prs', 'quy', 'ron', 'run', 'rus', 'sag', 'san',
#         'sat', 'scn', 'shn', 'sin', 'slk', 'slv', 'smo', 'sna', 'snd',
#         'som', 'sot', 'spa', 'srd', 'srp', 'ssw', 'sun', 'swe', 'swh',
#         'szl', 'tam', 'taq', 'tat', 'tel', 'tgk', 'tgl', 'tha', 'tir',
#         'tpi', 'tsn', 'tso', 'tuk', 'tum', 'tur', 'twi', 'tzm', 'uig',
#         'ukr', 'umb', 'urd', 'uzn', 'vec', 'vie', 'war', 'wol', 'xho',
#         'ydd', 'yor', 'yue', 'zho', 'zsm', 'zul'], dtype=object),
#  (195,))

# %% [markdown]
# # Final processing

# %% [markdown]
# ## Add macro languages

# %%
# add macro language
macros = [iso639.Language.from_part3(t).macrolanguage for t in flores_data['language']]
flores_data['language'] = [m if m is not None else l for m,l in zip(macros, flores_data['language'])]
# flores_data['is_macro'] = [True if m is not None else False for m in macros]

# %%
# convert all the names to a more readable form
flores_data['language'] = [iso639.Language.from_part3(p).name for p in flores_data['language']]
# flores_data['macro'] = [iso639.Language.from_part3(p).name for p in flores_data['macro']]

# %%
flores_data
# Out:
#                                                      text language
# 0       But shani hta Stanford dakkasu tsi dap kaw na ...   Kachin
# 1       Ndai arai hkyep gaw sinda mawng ana hpe sut su...   Kachin
# 2       JAS 39C Gripen mying ai pyenli gaw, buga ginda...   Kachin
# 3       Dai nbungli gau ai wa hpe Squadron a ning baw ...   Kachin
# 4       Buga shiga dap kaw na shapoi ai lam gaw, mahta...   Kachin
# ...                                                   ...      ...
# 202386  हिल स्टेशन के लेल पर्यटन के मौसम आम तौर पर भार...   Magahi
# 202387  हालांकि, सर्दी के दौरान ओकरा पास एगो अलग तरह क...   Magahi
# 202388  केवल कुछ एयरलाइंस अभीयो शोक किराया के पेशकश कर...   Magahi
# 202389  एयरलाइंस जे एगोर पेश करई हई ओइमे एयर कनाडा, डे...   Magahi
# 202390  सभे मामला में, अहां सीधे एयरलाइन के जौरे फोन द...   Magahi
#
# [202391 rows x 2 columns]

# %%
uniq = np.unique(flores_data.language)
uniq, uniq.shape
# Out:
# (array(['Achinese', 'Afrikaans', 'Akan', 'Albanian', 'Amharic', 'Arabic',
#         'Armenian', 'Assamese', 'Asturian', 'Awadhi', 'Aymara',
#         'Azerbaijani', 'Balinese', 'Bambara', 'Bashkir', 'Basque',
#         'Belarusian', 'Bemba (Zambia)', 'Bengali', 'Bhojpuri', 'Buginese',
#         'Bulgarian', 'Burmese', 'Catalan', 'Cebuano',
#         'Central Atlas Tamazight', 'Chhattisgarhi', 'Chinese', 'Chokwe',
#         'Crimean Tatar', 'Czech', 'Danish', 'Dinka', 'Dutch', 'Dyula',
#         'Dzongkha', 'English', 'Esperanto', 'Estonian', 'Ewe', 'Faroese',
#         'Fijian', 'Finnish', 'Fon', 'French', 'Friulian', 'Fulah',
#         'Galician', 'Ganda', 'Georgian', 'German', 'Guarani', 'Gujarati',
#         'Haitian', 'Hausa', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic',
#         'Igbo', 'Iloko', 'Irish', 'Italian', 'Japanese', 'Javanese',
#         'Kabiyè', 'Kabuverdianu', 'Kabyle', 'Kachin', 'Kamba (Kenya)',
#         'Kannada', 'Kanuri', 'Kashmiri', 'Kazakh', 'Khmer', 'Kikuyu',
#         'Kimbundu', 'Kinyarwanda', 'Kirghiz', 'Kongo', 'Korean', 'Kurdish',
#         'Lao', 'Latvian', 'Ligurian', 'Limburgan', 'Lingala', 'Lithuanian',
#         'Lombard', 'Luba-Lulua', 'Luo (Kenya and Tanzania)', 'Lushai',
#         'Luxembourgish', 'Macedonian', 'Magahi', 'Maithili', 'Malagasy',
#         'Malay (macrolanguage)', 'Malayalam', 'Maltese', 'Manipuri',
#         'Maori', 'Marathi', 'Modern Greek (1453-)', 'Mongolian', 'Mossi',
#         'Nepali (macrolanguage)', 'Norwegian', 'Nuer', 'Nyanja',
#         'Occitan (post 1500)', 'Oriya (macrolanguage)', 'Oromo',
#         'Pangasinan', 'Panjabi', 'Papiamento', 'Pedi', 'Persian', 'Polish',
#         'Portuguese', 'Pushto', 'Quechua', 'Romanian', 'Rundi', 'Russian',
#         'Samoan', 'Sango', 'Sanskrit', 'Santali', 'Sardinian',
#         'Scottish Gaelic', 'Serbo-Croatian', 'Shan', 'Shona', 'Sicilian',
#         'Silesian', 'Sindhi', 'Sinhala', 'Slovak', 'Slovenian', 'Somali',
#         'Southern Sotho', 'Spanish', 'Sundanese',
#         'Swahili (macrolanguage)', 'Swati', 'Swedish', 'Tagalog', 'Tajik',
#         'Tamashek', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan',
#         'Tigrinya', 'Tok Pisin', 'Tsonga', 'Tswana', 'Tumbuka', 'Turkish',
#         'Turkmen', 'Uighur', 'Ukrainian', 'Umbundu', 'Urdu', 'Uzbek',
#         'Venetian', 'Vietnamese', 'Waray (Philippines)', 'Welsh', 'Wolof',
#         'Xhosa', 'Yiddish', 'Yoruba', 'Zulu'], dtype=object),
#  (176,))

# %%
language_families = {
    'Achinese': 'Austronesian',
    'Afrikaans': 'Indo-European',
    'Akan': 'Niger-Congo',
    'Albanian': 'Indo-European',
    'Amharic': 'Afroasiatic',
    'Arabic': 'Afroasiatic',
    'Armenian': 'Indo-European',
    'Assamese': 'Indo-European',
    'Asturian': 'Indo-European',
    'Awadhi': 'Indo-European',
    'Aymara': 'Aymaran',
    'Azerbaijani': 'Turkic',
    'Balinese': 'Austronesian',
    'Bambara': 'Niger-Congo',
    'Bashkir': 'Turkic',
    'Basque': 'Language Isolate',
    'Belarusian': 'Indo-European',
    'Bemba (Zambia)': 'Niger-Congo',
    'Bengali': 'Indo-European',
    'Bhojpuri': 'Indo-European',
    'Buginese': 'Austronesian',
    'Bulgarian': 'Indo-European',
    'Burmese': 'Sino-Tibetan',
    'Catalan': 'Indo-European',
    'Cebuano': 'Austronesian',
    'Central Atlas Tamazight': 'Afroasiatic',
    'Chhattisgarhi': 'Indo-European',
    'Chinese': 'Sino-Tibetan',
    'Chokwe': 'Niger-Congo',
    'Crimean Tatar': 'Turkic',
    'Czech': 'Indo-European',
    'Danish': 'Indo-European',
    'Dinka': 'Nilo-Saharan',
    'Dutch': 'Indo-European',
    'Dyula': 'Niger-Congo',
    'Dzongkha': 'Sino-Tibetan',
    'English': 'Indo-European',
    'Esperanto': 'Constructed',
    'Estonian': 'Uralic',
    'Ewe': 'Niger-Congo',
    'Faroese': 'Indo-European',
    'Fijian': 'Austronesian',
    'Finnish': 'Uralic',
    'Fon': 'Niger-Congo',
    'French': 'Indo-European',
    'Friulian': 'Indo-European',
    'Fulah': 'Niger-Congo',
    'Galician': 'Indo-European',
    'Ganda': 'Niger-Congo',
    'Georgian': 'Kartvelian',
    'German': 'Indo-European',
    'Guarani': 'Tupian',
    'Gujarati': 'Indo-European',
    'Haitian': 'Indo-European',
    'Hausa': 'Afroasiatic',
    'Hebrew': 'Afroasiatic',
    'Hindi': 'Indo-European',
    'Hungarian': 'Uralic',
    'Icelandic': 'Indo-European',
    'Igbo': 'Niger-Congo',
    'Iloko': 'Austronesian',
    'Irish': 'Indo-European',
    'Italian': 'Indo-European',
    'Japanese': 'Japonic',
    'Javanese': 'Austronesian',
    'Kabiyè': 'Niger-Congo',
    'Kabuverdianu': 'Indo-European',
    'Kabyle': 'Afroasiatic',
    'Kachin': 'Sino-Tibetan',
    'Kamba (Kenya)': 'Niger-Congo',
    'Kannada': 'Dravidian',
    'Kanuri': 'Afroasiatic',
    'Kashmiri': 'Indo-European',
    'Kazakh': 'Turkic',
    'Khmer': 'Austroasiatic',
    'Kikuyu': 'Niger-Congo',
    'Kimbundu': 'Niger-Congo',
    'Kinyarwanda': 'Niger-Congo',
    'Kirghiz': 'Turkic',
    'Kongo': 'Niger-Congo',
    'Korean': 'Koreanic',
    'Kurdish': 'Indo-European',
    'Lao': 'Tai-Kadai',
    'Latvian': 'Indo-European',
    'Ligurian': 'Indo-European',
    'Limburgan': 'Indo-European',
    'Lingala': 'Niger-Congo',
    'Lithuanian': 'Indo-European',
    'Lombard': 'Indo-European',
    'Luba-Lulua': 'Niger-Congo',
    'Luo (Kenya and Tanzania)': 'Nilo-Saharan',
    'Lushai': 'Sino-Tibetan',
    'Luxembourgish': 'Indo-European',
    'Macedonian': 'Indo-European',
    'Magahi': 'Indo-European',
    'Maithili': 'Indo-European',
    'Malagasy': 'Austronesian',
    'Malay (macrolanguage)': 'Austronesian',
    'Malayalam': 'Dravidian',
    'Maltese': 'Afroasiatic',
    'Manipuri': 'Sino-Tibetan',
    'Maori': 'Austronesian',
    'Marathi': 'Indo-European',
    'Modern Greek (1453-)': 'Indo-European',
    'Mongolian': 'Mongolic',
    'Mossi': 'Niger-Congo',
    'Nepali (macrolanguage)': 'Indo-European',
    'Norwegian': 'Indo-European',
    'Nuer': 'Nilo-Saharan',
    'Nyanja': 'Niger-Congo',
    'Occitan (post 1500)': 'Indo-European',
    'Oriya (macrolanguage)': 'Indo-European',
    'Oromo': 'Afroasiatic',
    'Pangasinan': 'Austronesian',
    'Panjabi': 'Indo-European',
    'Papiamento': 'Creole',
    'Pedi': 'Niger-Congo',
    'Persian': 'Indo-European',
    'Polish': 'Indo-European',
    'Portuguese': 'Indo-European',
    'Pushto': 'Indo-European',
    'Quechua': 'Quechuan',
    'Romanian': 'Indo-European',
    'Rundi': 'Niger-Congo',
    'Russian': 'Indo-European',
    'Samoan': 'Austronesian',
    'Sango': 'Afroasiatic',
    'Sanskrit': 'Indo-European',
    'Santali': 'Austroasiatic',
    'Sardinian': 'Indo-European',
    'Scottish Gaelic': 'Indo-European',
    'Serbo-Croatian': 'Indo-European',
    'Shan': 'Tai-Kadai',
    'Shona': 'Niger-Congo',
    'Sicilian': 'Indo-European',
    'Silesian': 'Indo-European',
    'Sindhi': 'Indo-European',
    'Sinhala': 'Indo-European',
    'Slovak': 'Indo-European',
    'Slovenian': 'Indo-European',
    'Somali': 'Afroasiatic',
    'Southern Sotho': 'Niger-Congo',
    'Spanish': 'Indo-European',
    'Sundanese': 'Austronesian',
    'Swahili (macrolanguage)': 'Niger-Congo',
    'Swati': 'Niger-Congo',
    'Swedish': 'Indo-European',
    'Tagalog': 'Austronesian',
    'Tajik': 'Indo-European',
    'Tamashek': 'Afroasiatic',
    'Tamil': 'Dravidian',
    'Tatar': 'Turkic',
    'Telugu': 'Dravidian',
    'Thai': 'Tai-Kadai',
    'Tibetan': 'Sino-Tibetan',
    'Tigrinya': 'Afroasiatic',
    'Tok Pisin': 'Creole',
    'Tsonga': 'Niger-Congo',
    'Tswana': 'Niger-Congo',
    'Tumbuka': 'Niger-Congo',
    'Turkish': 'Turkic',
    'Turkmen': 'Turkic',
    'Uighur': 'Turkic',
    'Ukrainian': 'Indo-European',
    'Umbundu': 'Niger-Congo',
    'Urdu': 'Indo-European',
    'Uzbek': 'Turkic',
    'Venetian': 'Indo-European',
    'Vietnamese': 'Austroasiatic',
    'Waray (Philippines)': 'Austronesian',
    'Welsh': 'Indo-European',
    'Wolof': 'Niger-Congo',
    'Xhosa': 'Niger-Congo',
    'Yiddish': 'Indo-European',
    'Yoruba': 'Niger-Congo',
    'Zulu': 'Niger-Congo'
}

# %%
for name, df in flores_data.groupby('language'):
  if not name in language_families:
    print(name)

# %%
flores_data['macro'] = [language_families[n] for n in flores_data['language']]

# %%
np.unique(flores_data.macro)
# Out:
# array(['Afroasiatic', 'Austroasiatic', 'Austronesian', 'Aymaran',
#        'Constructed', 'Creole', 'Dravidian', 'Indo-European', 'Japonic',
#        'Kartvelian', 'Koreanic', 'Language Isolate', 'Mongolic',
#        'Niger-Congo', 'Nilo-Saharan', 'Quechuan', 'Sino-Tibetan',
#        'Tai-Kadai', 'Tupian', 'Turkic', 'Uralic'], dtype=object)

# %% [markdown]
# # Dump to file

# %%
flores_data
# Out:
#                                                      text language  \
# 0       But shani hta Stanford dakkasu tsi dap kaw na ...   Kachin
# 1       Ndai arai hkyep gaw sinda mawng ana hpe sut su...   Kachin
# 2       JAS 39C Gripen mying ai pyenli gaw, buga ginda...   Kachin
# 3       Dai nbungli gau ai wa hpe Squadron a ning baw ...   Kachin
# 4       Buga shiga dap kaw na shapoi ai lam gaw, mahta...   Kachin
# ...                                                   ...      ...
# 202386  हिल स्टेशन के लेल पर्यटन के मौसम आम तौर पर भार...   Magahi
# 202387  हालांकि, सर्दी के दौरान ओकरा पास एगो अलग तरह क...   Magahi
# 202388  केवल कुछ एयरलाइंस अभीयो शोक किराया के पेशकश कर...   Magahi
# 202389  एयरलाइंस जे एगोर पेश करई हई ओइमे एयर कनाडा, डे...   Magahi
# 202390  सभे मामला में, अहां सीधे एयरलाइन के जौरे फोन द...   Magahi
#
#                 macro
# 0        Sino-Tibetan
# 1        Sino-Tibetan
# 2        Sino-Tibetan
# 3        Sino-Tibetan
# 4        Sino-Tibetan
# ...               ...
# 202386  Indo-European
# 202387  Indo-European
# 202388  Indo-European
# 202389  Indo-European
# 202390  Indo-European
#
# [202391 rows x 3 columns]

# %%
flores_data.to_feather('/content/drive/MyDrive/flores_dataset.feather')

# %%
# data2 = pd.read_feather('/content/drive/MyDrive/final_dataset.feather')

# %% [markdown]
# ## Try ML methods

# %%
# x_train, x_test, y_train, y_test = train_test_split(flores_data.text.values, flores_data.language.values, test_size=0.2, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(flores_data.text.values, flores_data.macro.values, test_size=0.2, random_state=42)

# function to clean text
def clean_txt(text):
    text=text.lower()
    text=re.sub(r'[^\w\s]',' ',text)
    text=re.sub(r'[_0-9]',' ',text)
    text=re.sub(r'\s\s+',' ',text)
    return text

x_train = [clean_txt(text) for text in x_train]
x_test = [clean_txt(text) for text in x_test]

# using Tfidf Vectorizer:
tfidf = TfidfVectorizer()
tfidf.fit(x_train)
x_train_ready = tfidf.transform(x_train)
x_test_ready = tfidf.transform(x_test)

x_train_ready,x_test_ready

enc = LabelEncoder()
enc.fit(y_train)
y_train_ready = enc.transform(y_train)
y_test_ready = enc.transform(y_test)
# storing encoded label hast list as 'labels'
labels = enc.classes_
nb = MultinomialNB(fit_prior=False)
from sklearn.metrics import classification_report
# Fit the Multinomial Naive Bayes model
nb.fit(x_train_ready, y_train_ready)
# Make predictions on the test data
y_pred = nb.predict(x_test_ready)
# Reverse transform the encoded predictions to original labels
y_pred_original = enc.inverse_transform(y_pred)
# Generate a classification report
classification_rep = classification_report(y_test, y_pred_original, target_names=labels)
print(classification_rep)
# Out:
#                   precision    recall  f1-score   support
#
#      Afroasiatic       0.88      0.99      0.93      4621
#    Austroasiatic       1.00      1.00      1.00       608
#     Austronesian       1.00      1.00      1.00      4101
#          Aymaran       1.00      0.93      0.96       185
#      Constructed       1.00      0.86      0.93       191
#           Creole       1.00      0.85      0.92       426
#        Dravidian       1.00      1.00      1.00       778
#    Indo-European       0.98      1.00      0.99     15529
#          Japonic       0.89      0.17      0.28       203
#       Kartvelian       1.00      0.99      0.99       200
#         Koreanic       1.00      0.96      0.98       199
# Language Isolate       1.00      0.96      0.98       174
#         Mongolic       0.99      1.00      1.00       190
#      Niger-Congo       0.99      1.00      0.99      6934
#     Nilo-Saharan       1.00      0.99      0.99       537
#         Quechuan       1.00      0.94      0.97       212
#     Sino-Tibetan       1.00      0.73      0.84      1810
#        Tai-Kadai       1.00      1.00      1.00       602
#           Tupian       1.00      0.94      0.97       222
#           Turkic       1.00      0.97      0.99      2179
#           Uralic       1.00      0.95      0.98       578
#
#         accuracy                           0.98     40479
#        macro avg       0.99      0.92      0.94     40479
#     weighted avg       0.98      0.98      0.97     40479

# %%
# use pipeline to combine prefitted vectorizer and trained model into one object
model = Pipeline([('vectorizer',tfidf),('nb',nb)])
# function to predict language from text
def predict(text):
    pred = model.predict([clean_txt(text)])
    ans = enc.inverse_transform(pred)
    return ans[0]
#       english                     hindi                     spanish?                        russian                   french
predict('my name is harsh'), predict('मेरा नाम हर्ष हे'), predict('mi nombre es harsh'), predict('меня зовут Харш'), predict('mon nom est harsh')
# Out:
# ('Indo-European',
#  'Indo-European',
#  'Indo-European',
#  'Indo-European',
#  'Indo-European')

# %%
#       zulu                    japanese                          chinese
predict('igama lami linzima'), predict('你好，我是一个喜欢了解一些不同主题的人'), predict('こんにちは、私はいくつかの異なるトピックについて学ぶのが好きな男です。 私は応用数学の学生で、どこまでもクールな男です。')
# Out:
# ('Niger-Congo', 'Sino-Tibetan', 'Afroasiatic')

# %%
for name, df in flores_data.groupby('macro'):
  # x_train, x_test, y_train, y_test = train_test_split(flores_data.text.values, flores_data.language.values, test_size=0.2, random_state=42)
  x_train, x_test, y_train, y_test = train_test_split(df.text.values, df.language.values, test_size=0.2, random_state=42)

  # function to clean text
  def clean_txt(text):
      text=text.lower()
      text=re.sub(r'[^\w\s]',' ',text)
      text=re.sub(r'[_0-9]',' ',text)
      text=re.sub(r'\s\s+',' ',text)
      return text

  x_train = [clean_txt(text) for text in x_train];
  x_test = [clean_txt(text) for text in x_test];

  # using Tfidf Vectorizer:
  tfidf = TfidfVectorizer()
  tfidf.fit(x_train)
  x_train_ready = tfidf.transform(x_train)
  x_test_ready = tfidf.transform(x_test)

  x_train_ready,x_test_ready

  enc = LabelEncoder()
  enc.fit(y_train)
  y_train_ready = enc.transform(y_train)
  y_test_ready = enc.transform(y_test)
  # storing encoded label hast list as 'labels'
  labels = enc.classes_
  nb = MultinomialNB()
  from sklearn.metrics import classification_report
  # Fit the Multinomial Naive Bayes model
  nb.fit(x_train_ready, y_train_ready)
  # Make predictions on the test data
  y_pred = nb.predict(x_test_ready)
  # Reverse transform the encoded predictions to original labels
  y_pred_original = enc.inverse_transform(y_pred)
  # Generate a classification report
  classification_rep = classification_report(y_test, y_pred_original, target_names=labels)
  print('#'*10)
  print(name)
  print('#'*10)
  print(classification_rep)
  print()
# Out:
# ##########
# Afroasiatic
# ##########
#                          precision    recall  f1-score   support
#
#                 Amharic       1.00      0.93      0.96       200
#                  Arabic       0.95      1.00      0.97      1831
# Central Atlas Tamazight       1.00      0.97      0.99       190
#                   Hausa       1.00      1.00      1.00       217
#                  Hebrew       1.00      0.92      0.96       217
#                  Kabyle       1.00      0.98      0.99       201
#                  Kanuri       1.00      0.92      0.96       391
#                 Maltese       1.00      0.98      0.99       201
#                   Oromo       1.00      0.98      0.99       198
#                   Sango       1.00      1.00      1.00       214
#                  Somali       1.00      1.00      1.00       174
#                Tamashek       1.00      0.99      1.00       349
#                Tigrinya       1.00      0.96      0.98       204
#
#                accuracy                           0.98      4587
#               macro avg       1.00      0.97      0.98      4587
#            weighted avg       0.98      0.98      0.98      4587
#
#
# ##########
# Austroasiatic
# ##########
#               precision    recall  f1-score   support
#
#        Khmer       1.00      1.00      1.00       187
#      Santali       1.00      1.00      1.00       192
#   Vietnamese       1.00      1.00      1.00       220
#
#     accuracy                           1.00       599
#    macro avg       1.00      1.00      1.00       599
# weighted avg       1.00      1.00      1.00       599
#
#
# ##########
# Austronesian
# ##########
#                        precision    recall  f1-score   support
#
#              Achinese       1.00      0.96      0.98       369
#              Balinese       1.00      0.91      0.95       196
#              Buginese       1.00      0.83      0.91       218
#               Cebuano       1.00      0.99      1.00       191
#                Fijian       1.00      1.00      1.00       200
#                 Iloko       1.00      1.00      1.00       205
#              Javanese       1.00      0.90      0.95       174
#              Malagasy       1.00      1.00      1.00       219
# Malay (macrolanguage)       0.91      1.00      0.95      1213
#                 Maori       1.00      1.00      1.00       203
#            Pangasinan       1.00      1.00      1.00       212
#                Samoan       1.00      1.00      1.00       214
#             Sundanese       1.00      0.80      0.89       198
#               Tagalog       1.00      1.00      1.00       173
#   Waray (Philippines)       1.00      1.00      1.00       203
#
#              accuracy                           0.97      4188
#             macro avg       0.99      0.96      0.98      4188
#          weighted avg       0.97      0.97      0.97      4188
#
#
# ##########
# Aymaran
# ##########
#               precision    recall  f1-score   support
#
#       Aymara       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Constructed
# ##########
#               precision    recall  f1-score   support
#
#    Esperanto       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Creole
# ##########
#               precision    recall  f1-score   support
#
#   Papiamento       1.00      0.99      1.00       193
#    Tok Pisin       1.00      1.00      1.00       206
#
#     accuracy                           1.00       399
#    macro avg       1.00      1.00      1.00       399
# weighted avg       1.00      1.00      1.00       399
#
#
# ##########
# Dravidian
# ##########
#               precision    recall  f1-score   support
#
#      Kannada       1.00      1.00      1.00       190
#    Malayalam       1.00      1.00      1.00       210
#        Tamil       1.00      1.00      1.00       189
#       Telugu       1.00      1.00      1.00       209
#
#     accuracy                           1.00       798
#    macro avg       1.00      1.00      1.00       798
# weighted avg       1.00      1.00      1.00       798
#
#
# ##########
# Indo-European
# ##########
#                         precision    recall  f1-score   support
#
#              Afrikaans       0.99      1.00      0.99       194
#               Albanian       1.00      1.00      1.00       199
#               Armenian       1.00      0.98      0.99       205
#               Assamese       0.99      0.99      0.99       186
#               Asturian       0.99      0.94      0.96       203
#                 Awadhi       0.70      0.82      0.76       175
#             Belarusian       1.00      0.97      0.99       174
#                Bengali       0.99      0.99      0.99       184
#               Bhojpuri       0.89      0.81      0.85       192
#              Bulgarian       0.99      0.95      0.97       196
#                Catalan       0.99      1.00      1.00       203
#          Chhattisgarhi       0.93      0.83      0.88       225
#                  Czech       1.00      0.80      0.89       220
#                 Danish       1.00      0.32      0.49       197
#                  Dutch       0.99      1.00      1.00       195
#                English       0.99      1.00      1.00       192
#                Faroese       1.00      0.98      0.99       217
#                 French       1.00      1.00      1.00       183
#               Friulian       1.00      1.00      1.00       181
#               Galician       0.97      0.98      0.98       188
#                 German       0.99      0.99      0.99       197
#               Gujarati       1.00      1.00      1.00       201
#                Haitian       0.99      1.00      1.00       190
#                  Hindi       0.89      0.83      0.86       198
#              Icelandic       1.00      0.96      0.98       179
#                  Irish       1.00      0.99      1.00       222
#                Italian       1.00      0.99      1.00       203
#           Kabuverdianu       1.00      1.00      1.00       210
#               Kashmiri       0.95      0.98      0.97       384
#                Kurdish       0.99      1.00      1.00       381
#                Latvian       0.98      0.99      0.99       396
#               Ligurian       1.00      0.99      0.99       218
#              Limburgan       1.00      0.97      0.99       191
#             Lithuanian       1.00      0.88      0.94       197
#                Lombard       1.00      1.00      1.00       209
#          Luxembourgish       1.00      0.99      1.00       213
#             Macedonian       1.00      0.95      0.98       208
#                 Magahi       0.92      0.92      0.92       220
#               Maithili       0.93      0.97      0.95       225
#                Marathi       0.97      0.93      0.95       215
#   Modern Greek (1453-)       1.00      1.00      1.00       198
# Nepali (macrolanguage)       0.97      0.94      0.95       208
#              Norwegian       0.70      1.00      0.83       400
#    Occitan (post 1500)       0.99      1.00      1.00       187
#  Oriya (macrolanguage)       1.00      1.00      1.00       186
#                Panjabi       1.00      1.00      1.00       207
#                Persian       1.00      1.00      1.00       396
#                 Polish       1.00      0.87      0.93       210
#             Portuguese       0.98      0.97      0.98       194
#                 Pushto       1.00      1.00      1.00       205
#               Romanian       1.00      1.00      1.00       224
#                Russian       1.00      0.92      0.96       170
#               Sanskrit       0.90      0.98      0.94       190
#              Sardinian       0.99      1.00      1.00       190
#        Scottish Gaelic       1.00      1.00      1.00       207
#         Serbo-Croatian       0.72      1.00      0.84       625
#               Sicilian       1.00      1.00      1.00       193
#               Silesian       0.98      0.91      0.94       195
#                 Sindhi       1.00      1.00      1.00       200
#                Sinhala       1.00      1.00      1.00       210
#                 Slovak       0.99      0.86      0.92       194
#              Slovenian       1.00      0.72      0.84       198
#                Spanish       0.95      0.98      0.97       198
#                Swedish       1.00      0.90      0.95       194
#                  Tajik       1.00      1.00      1.00       202
#              Ukrainian       1.00      0.95      0.98       187
#                   Urdu       0.99      1.00      1.00       218
#               Venetian       0.99      0.99      0.99       192
#                  Welsh       1.00      0.99      1.00       203
#                Yiddish       1.00      1.00      1.00       207
#
#               accuracy                           0.96     15354
#              macro avg       0.97      0.95      0.96     15354
#           weighted avg       0.96      0.96      0.96     15354
#
#
# ##########
# Japonic
# ##########
#               precision    recall  f1-score   support
#
#     Japanese       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Kartvelian
# ##########
#               precision    recall  f1-score   support
#
#     Georgian       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Koreanic
# ##########
#               precision    recall  f1-score   support
#
#       Korean       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Language Isolate
# ##########
#               precision    recall  f1-score   support
#
#       Basque       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Mongolic
# ##########
#               precision    recall  f1-score   support
#
#    Mongolian       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Niger-Congo
# ##########
#                          precision    recall  f1-score   support
#
#                    Akan       0.84      1.00      0.91       394
#                 Bambara       0.96      0.90      0.93       208
#          Bemba (Zambia)       0.99      0.99      0.99       201
#                  Chokwe       0.99      0.99      0.99       188
#                   Dyula       1.00      0.96      0.98       204
#                     Ewe       1.00      1.00      1.00       202
#                     Fon       1.00      1.00      1.00       192
#                   Fulah       1.00      1.00      1.00       196
#                   Ganda       0.99      0.94      0.97       212
#                    Igbo       1.00      1.00      1.00       194
#                  Kabiyè       1.00      1.00      1.00       185
#           Kamba (Kenya)       1.00      0.98      0.99       195
#                  Kikuyu       0.89      0.99      0.94       200
#                Kimbundu       1.00      0.99      1.00       186
#             Kinyarwanda       0.85      0.97      0.91       177
#                   Kongo       1.00      1.00      1.00       213
#                 Lingala       1.00      1.00      1.00       177
#              Luba-Lulua       1.00      1.00      1.00       206
#                   Mossi       1.00      1.00      1.00       201
#                  Nyanja       1.00      0.99      0.99       220
#                    Pedi       0.99      1.00      0.99       206
#                   Rundi       0.97      0.85      0.91       201
#                   Shona       1.00      0.97      0.99       207
#          Southern Sotho       0.99      0.99      0.99       179
# Swahili (macrolanguage)       1.00      1.00      1.00       201
#                   Swati       1.00      0.92      0.96       200
#                  Tsonga       0.99      1.00      0.99       208
#                  Tswana       0.98      0.99      0.98       182
#                 Tumbuka       0.98      1.00      0.99       191
#                 Umbundu       1.00      1.00      1.00       218
#                   Wolof       1.00      1.00      1.00       222
#                   Xhosa       0.97      0.83      0.89       208
#                  Yoruba       1.00      1.00      1.00       182
#                    Zulu       0.94      0.90      0.92       223
#
#                accuracy                           0.97      6979
#               macro avg       0.98      0.97      0.98      6979
#            weighted avg       0.98      0.97      0.97      6979
#
#
# ##########
# Nilo-Saharan
# ##########
#                           precision    recall  f1-score   support
#
#                    Dinka       1.00      1.00      1.00       192
# Luo (Kenya and Tanzania)       1.00      1.00      1.00       220
#                     Nuer       1.00      1.00      1.00       187
#
#                 accuracy                           1.00       599
#                macro avg       1.00      1.00      1.00       599
#             weighted avg       1.00      1.00      1.00       599
#
#
# ##########
# Quechuan
# ##########
#               precision    recall  f1-score   support
#
#      Quechua       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Sino-Tibetan
# ##########
#               precision    recall  f1-score   support
#
#      Burmese       1.00      1.00      1.00       184
#      Chinese       1.00      1.00      1.00       620
#     Dzongkha       0.85      0.99      0.91       187
#       Kachin       1.00      1.00      1.00       188
#       Lushai       1.00      1.00      1.00       209
#     Manipuri       1.00      1.00      1.00       195
#      Tibetan       0.99      0.84      0.91       212
#
#     accuracy                           0.98      1795
#    macro avg       0.98      0.98      0.97      1795
# weighted avg       0.98      0.98      0.98      1795
#
#
# ##########
# Tai-Kadai
# ##########
#               precision    recall  f1-score   support
#
#          Lao       1.00      1.00      1.00       192
#         Shan       1.00      1.00      1.00       187
#         Thai       1.00      1.00      1.00       220
#
#     accuracy                           1.00       599
#    macro avg       1.00      1.00      1.00       599
# weighted avg       1.00      1.00      1.00       599
#
#
# ##########
# Tupian
# ##########
#               precision    recall  f1-score   support
#
#      Guarani       1.00      1.00      1.00       200
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# ##########
# Turkic
# ##########
#                precision    recall  f1-score   support
#
#   Azerbaijani       0.95      1.00      0.97       417
#       Bashkir       0.99      0.98      0.99       201
# Crimean Tatar       0.98      0.96      0.97       184
#        Kazakh       1.00      0.98      0.99       207
#       Kirghiz       1.00      0.99      1.00       200
#         Tatar       0.99      1.00      0.99       203
#       Turkish       0.99      0.95      0.97       209
#       Turkmen       0.99      0.98      0.99       200
#        Uighur       1.00      1.00      1.00       177
#         Uzbek       1.00      0.99      0.99       196
#
#      accuracy                           0.98      2194
#     macro avg       0.99      0.98      0.99      2194
#  weighted avg       0.99      0.98      0.98      2194
#
#
# ##########
# Uralic
# ##########
#               precision    recall  f1-score   support
#
#     Estonian       0.99      0.99      0.99       192
#      Finnish       0.99      0.99      0.99       220
#    Hungarian       0.99      1.00      1.00       187
#
#     accuracy                           0.99       599
#    macro avg       0.99      0.99      0.99       599
# weighted avg       0.99      0.99      0.99       599

# %%
x_train, x_test, y_train, y_test = train_test_split(flores_data.text.values, flores_data.language.values, test_size=0.2, random_state=42)

# function to clean text
def clean_txt(text):
    text=text.lower()
    text=re.sub(r'[^\w\s]',' ',text)
    text=re.sub(r'[_0-9]',' ',text)
    text=re.sub(r'\s\s+',' ',text)
    return text

x_train = [clean_txt(text) for text in x_train]
x_test = [clean_txt(text) for text in x_test]

# using Tfidf Vectorizer:
tfidf = TfidfVectorizer()
tfidf.fit(x_train)
x_train_ready = tfidf.transform(x_train)
x_test_ready = tfidf.transform(x_test)

x_train_ready,x_test_ready

enc = LabelEncoder()
enc.fit(y_train)
y_train_ready = enc.transform(y_train)
y_test_ready = enc.transform(y_test)
# storing encoded label hast list as 'labels'
labels = enc.classes_
nb = MultinomialNB(fit_prior=False)
from sklearn.metrics import classification_report
# Fit the Multinomial Naive Bayes model
nb.fit(x_train_ready, y_train_ready)
# Make predictions on the test data
y_pred = nb.predict(x_test_ready)
# Reverse transform the encoded predictions to original labels
y_pred_original = enc.inverse_transform(y_pred)
# Generate a classification report
classification_rep = classification_report(y_test, y_pred_original, target_names=labels)
print(classification_rep)
# Out:
#                           precision    recall  f1-score   support
#
#                 Achinese       0.37      1.00      0.54       376
#                Afrikaans       0.99      0.99      0.99       192
#                     Akan       0.97      1.00      0.98       416
#                 Albanian       1.00      1.00      1.00       190
#                  Amharic       1.00      1.00      1.00       192
#                   Arabic       0.99      1.00      0.99      1858
#                 Armenian       1.00      1.00      1.00       196
#                 Assamese       0.99      1.00      0.99       206
#                 Asturian       0.99      0.95      0.97       207
#                   Awadhi       0.81      0.82      0.81       218
#                   Aymara       1.00      0.98      0.99       185
#              Azerbaijani       1.00      0.91      0.95       400
#                 Balinese       1.00      0.94      0.97       200
#                  Bambara       0.95      0.93      0.94       195
#                  Bashkir       1.00      0.97      0.98       198
#                   Basque       1.00      0.99      1.00       174
#               Belarusian       1.00      0.99      1.00       200
#           Bemba (Zambia)       1.00      1.00      1.00       211
#                  Bengali       0.99      0.98      0.99       200
#                 Bhojpuri       0.86      0.80      0.83       199
#                 Buginese       1.00      0.95      0.98       192
#                Bulgarian       0.98      0.98      0.98       190
#                  Burmese       1.00      1.00      1.00       214
#                  Catalan       1.00      1.00      1.00       233
#                  Cebuano       1.00      1.00      1.00       189
#  Central Atlas Tamazight       1.00      1.00      1.00       192
#            Chhattisgarhi       0.87      0.86      0.86       205
#                  Chinese       0.96      0.21      0.35       613
#                   Chokwe       1.00      0.99      1.00       193
#            Crimean Tatar       0.98      0.97      0.98       183
#                    Czech       0.98      0.98      0.98       195
#                   Danish       1.00      0.62      0.76       195
#                    Dinka       0.99      1.00      1.00       193
#                    Dutch       0.96      1.00      0.98       192
#                    Dyula       0.99      0.96      0.98       204
#                 Dzongkha       0.92      0.96      0.94       200
#                  English       0.93      1.00      0.96       198
#                Esperanto       1.00      0.99      1.00       191
#                 Estonian       1.00      0.98      0.99       187
#                      Ewe       0.99      1.00      1.00       186
#                  Faroese       1.00      0.99      1.00       189
#                   Fijian       0.99      1.00      1.00       173
#                  Finnish       1.00      0.99      0.99       195
#                      Fon       0.99      1.00      1.00       190
#                   French       0.99      1.00      0.99       199
#                 Friulian       0.99      1.00      1.00       195
#                    Fulah       1.00      1.00      1.00       193
#                 Galician       0.98      0.97      0.97       216
#                    Ganda       1.00      0.96      0.98       213
#                 Georgian       1.00      1.00      1.00       200
#                   German       0.99      1.00      0.99       209
#                  Guarani       1.00      1.00      1.00       222
#                 Gujarati       1.00      1.00      1.00       222
#                  Haitian       1.00      1.00      1.00       210
#                    Hausa       0.98      1.00      0.99       185
#                   Hebrew       1.00      0.99      1.00       199
#                    Hindi       0.87      0.85      0.86       205
#                Hungarian       1.00      0.99      0.99       196
#                Icelandic       1.00      0.99      1.00       195
#                     Igbo       0.99      1.00      1.00       196
#                    Iloko       1.00      1.00      1.00       190
#                    Irish       0.99      0.99      0.99       200
#                  Italian       1.00      0.99      1.00       217
#                 Japanese       0.94      0.17      0.28       203
#                 Javanese       1.00      0.98      0.99       184
#                   Kabiyè       1.00      1.00      1.00       179
#             Kabuverdianu       1.00      1.00      1.00       201
#                   Kabyle       1.00      0.99      1.00       197
#                   Kachin       1.00      1.00      1.00       203
#            Kamba (Kenya)       1.00      0.96      0.98       193
#                  Kannada       1.00      1.00      1.00       181
#                   Kanuri       1.00      0.95      0.97       393
#                 Kashmiri       1.00      0.97      0.98       395
#                   Kazakh       1.00      0.99      0.99       200
#                    Khmer       1.00      1.00      1.00       222
#                   Kikuyu       0.91      1.00      0.95       192
#                 Kimbundu       1.00      1.00      1.00       186
#              Kinyarwanda       0.90      0.95      0.92       196
#                  Kirghiz       1.00      1.00      1.00       223
#                    Kongo       0.99      1.00      0.99       194
#                   Korean       1.00      0.98      0.99       199
#                  Kurdish       1.00      1.00      1.00       426
#                      Lao       1.00      1.00      1.00       194
#                  Latvian       1.00      0.99      1.00       408
#                 Ligurian       1.00      1.00      1.00       196
#                Limburgan       1.00      0.96      0.98       181
#                  Lingala       1.00      1.00      1.00       186
#               Lithuanian       1.00      0.99      0.99       201
#                  Lombard       1.00      0.99      0.99       210
#               Luba-Lulua       1.00      1.00      1.00       184
# Luo (Kenya and Tanzania)       0.99      1.00      0.99       176
#                   Lushai       0.99      1.00      1.00       186
#            Luxembourgish       1.00      1.00      1.00       202
#               Macedonian       0.97      1.00      0.98       207
#                   Magahi       0.93      0.94      0.93       201
#                 Maithili       0.91      0.97      0.94       189
#                 Malagasy       1.00      1.00      1.00       217
#    Malay (macrolanguage)       0.93      1.00      0.97      1204
#                Malayalam       1.00      1.00      1.00       192
#                  Maltese       0.99      1.00      0.99       208
#                 Manipuri       1.00      1.00      1.00       202
#                    Maori       0.99      1.00      1.00       186
#                  Marathi       0.98      0.95      0.96       204
#     Modern Greek (1453-)       1.00      1.00      1.00       206
#                Mongolian       0.99      1.00      1.00       190
#                    Mossi       1.00      0.99      1.00       189
#   Nepali (macrolanguage)       0.94      0.97      0.96       208
#                Norwegian       0.83      1.00      0.90       381
#                     Nuer       0.99      0.99      0.99       168
#                   Nyanja       1.00      0.99      0.99       203
#      Occitan (post 1500)       1.00      1.00      1.00       226
#    Oriya (macrolanguage)       1.00      1.00      1.00       203
#                    Oromo       1.00      1.00      1.00       203
#               Pangasinan       1.00      0.99      1.00       198
#                  Panjabi       1.00      1.00      1.00       213
#               Papiamento       1.00      1.00      1.00       213
#                     Pedi       0.98      0.99      0.99       181
#                  Persian       0.98      1.00      0.99       398
#                   Polish       0.97      0.94      0.96       198
#               Portuguese       0.98      0.98      0.98       204
#                   Pushto       0.99      1.00      1.00       191
#                  Quechua       1.00      1.00      1.00       212
#                 Romanian       1.00      1.00      1.00       222
#                    Rundi       0.94      0.88      0.91       194
#                  Russian       1.00      0.98      0.99       212
#                   Samoan       0.99      1.00      0.99       189
#                    Sango       0.99      1.00      0.99       202
#                 Sanskrit       0.91      0.97      0.94       195
#                  Santali       1.00      1.00      1.00       176
#                Sardinian       0.98      1.00      0.99       189
#          Scottish Gaelic       0.99      1.00      0.99       187
#           Serbo-Croatian       0.97      0.99      0.98       578
#                     Shan       1.00      1.00      1.00       209
#                    Shona       1.00      0.99      0.99       203
#                 Sicilian       0.99      1.00      0.99       179
#                 Silesian       0.96      0.97      0.97       194
#                   Sindhi       1.00      1.00      1.00       220
#                  Sinhala       1.00      1.00      1.00       207
#                   Slovak       0.99      0.96      0.98       195
#                Slovenian       0.99      0.95      0.97       203
#                   Somali       1.00      1.00      1.00       185
#           Southern Sotho       0.99      0.99      0.99       201
#                  Spanish       0.89      1.00      0.94       180
#                Sundanese       1.00      0.93      0.96       199
#  Swahili (macrolanguage)       1.00      1.00      1.00       225
#                    Swati       0.98      0.92      0.95       206
#                  Swedish       1.00      0.98      0.99       196
#                  Tagalog       1.00      1.00      1.00       188
#                    Tajik       1.00      1.00      1.00       213
#                 Tamashek       1.00      1.00      1.00       410
#                    Tamil       1.00      1.00      1.00       222
#                    Tatar       0.98      0.99      0.99       181
#                   Telugu       1.00      1.00      1.00       183
#                     Thai       1.00      1.00      1.00       199
#                  Tibetan       0.96      0.91      0.94       192
#                 Tigrinya       1.00      1.00      1.00       197
#                Tok Pisin       1.00      1.00      1.00       213
#                   Tsonga       0.98      1.00      0.99       202
#                   Tswana       0.96      0.99      0.98       192
#                  Tumbuka       0.98      1.00      0.99       194
#                  Turkish       0.99      0.97      0.98       198
#                  Turkmen       1.00      1.00      1.00       216
#                   Uighur       1.00      1.00      1.00       187
#                Ukrainian       0.98      0.99      0.99       192
#                  Umbundu       1.00      0.99      0.99       206
#                     Urdu       0.99      1.00      1.00       195
#                    Uzbek       1.00      1.00      1.00       193
#                 Venetian       0.99      1.00      0.99       204
#               Vietnamese       1.00      1.00      1.00       210
#      Waray (Philippines)       0.99      1.00      0.99       216
#                    Welsh       1.00      1.00      1.00       228
#                    Wolof       1.00      1.00      1.00       207
#                    Xhosa       0.99      0.88      0.93       212
#                  Yiddish       1.00      1.00      1.00       218
#                   Yoruba       1.00      1.00      1.00       201
#                     Zulu       0.90      0.95      0.93       211
#
#                 accuracy                           0.97     40479
#                macro avg       0.98      0.97      0.97     40479
#             weighted avg       0.98      0.97      0.97     40479
